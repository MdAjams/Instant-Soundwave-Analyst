# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Data load
df=pd.read_csv("mxmh_survey_cleaned.csv")
df.head()
# Out:
#              timestamp   age primary_streaming_service  hours_per_day  \
# 0  2022-08-27 19:29:02  18.0                   Spotify            3.0
# 1  2022-08-27 19:57:31  63.0                   Pandora            1.5
# 2  2022-08-27 21:28:18  18.0                   Spotify            4.0
# 3  2022-08-27 21:40:40  61.0             YouTube Music            2.5
# 4  2022-08-27 21:54:47  18.0                   Spotify            4.0
#
#   while_working instrumentalist composer         fav_genre exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   foreign_languages  ...     frequency_rb    frequency_rap   frequency_rock  \
# ...

# %% [markdown]
# # 1️⃣ Music Effect on Mental State (Overall)
# #### Distribution of Satisfaction Responses
#
#     🎶 Let's see how many people believe that music truly helps their mental health!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   timestamp                   736 non-null    object
#  1   age                         736 non-null    float64
#  2   primary_streaming_service   736 non-null    object
#  3   hours_per_day               736 non-null    float64
#  4   while_working               736 non-null    object
#  5   instrumentalist             736 non-null    object
#  6   composer                    736 non-null    object
#  7   fav_genre                   736 non-null    object
#  8   exploratory                 736 non-null    object
#  9   foreign_languages           736 non-null    object
#  10  bpm                         736 non-null    float64
#  11  frequency_classical         736 non-null    object
#  12  frequency_country           736 non-null    object
# ...

# %%
# Music effect on emotions
plt.figure(figsize=(7, 4))
sns.countplot(data=df, x='music_effects', palette='Set1')
plt.title("Does Music Help Your Mental State?")
plt.xlabel("Music Effect")
plt.ylabel("Number of Respondents")
plt.xticks(rotation=45)
plt.show()

# Overall Distribution of Music Effects
plt.figure(figsize=(7, 5))
sns.countplot(data=df, x='music_effects', palette='cool')
plt.title("Impact of Music on Mental State 🎶🧠")
plt.xlabel("Music Effects")
plt.ylabel("Number of Respondents")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_8452\3399342467.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='music_effects', palette='Set1')
# C:\Users\dell\AppData\Local\Temp\ipykernel_8452\3399342467.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='music_effects', palette='cool')
# C:\Users\dell\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127926 (\N{MULTIPLE MUSICAL NOTES}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129504 (\N{BRAIN}) missing from font(s) DejaVu Sans.
# ...

# %% [markdown]
# #  Analyze Music Effects by Age Group
#      Let's explore how different age groups perceive the emotional benefits of music!

# %%
# Create Age Groups
bins = [12, 18, 25, 35, 50, 70]
labels = ['Teen', 'Young Adult', 'Adult', 'Middle Aged', 'Senior']
df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels)

# Plot
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='age_group', hue='music_effects', palette='Spectral')
plt.title("Impact of Music on Mental State by Age Group 🎧")
plt.xlabel("Age Group")
plt.ylabel("Number of Respondents")
plt.legend(title="Music Effects")
plt.show()
# Out:
# C:\Users\dell\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127911 (\N{HEADPHONE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Analyze Music Effects by Primary Streaming Service
#     🎶 Do Spotify, YouTube, or Apple Music users feel differently about music's impact? Let's compare!

# %%
# Top Streaming Services
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='primary_streaming_service', hue='music_effects', palette='Set2')
plt.title("Impact of Music Based on Streaming Platforms 📱🎵")
plt.xlabel("Primary Streaming Service")
plt.ylabel("Number of Respondents")
plt.xticks(rotation=45)
plt.legend(title="Music Effects")
plt.show()
# Out:
# C:\Users\dell\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128241 (\N{MOBILE PHONE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127925 (\N{MUSICAL NOTE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Analyze Hours per Day vs Music Effects
#     ⏳ Does listening to music for more hours relate to feeling more emotionally better?

# %%
# Average Listening Hours Based on Music Effects
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x='music_effects', y='hours_per_day', palette='Pastel1')
plt.title("Music Listening Time vs Mental Satisfaction ⏳🎶")
plt.xlabel("Music Effects")
plt.ylabel("Hours Per Day")
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_8452\2805823290.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='music_effects', y='hours_per_day', palette='Pastel1')
# C:\Users\dell\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9203 (\N{HOURGLASS WITH FLOWING SAND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127926 (\N{MULTIPLE MUSICAL NOTES}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Correlation with Anxiety, Depression, Insomnia, OCD
#     🔗 How closely is the emotional effect of music connected to mental health issues like anxiety and depression?

# %%
# Encode 'music_effects' into numeric values
df['music_effects_num'] = df['music_effects'].map({'Helps a lot': 3, 'Helps somewhat': 2, 'Neutral': 1, 'Does not help': 0})

# Correlation Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(df[['music_effects_num', 'anxiety', 'depression', 'insomnia', 'ocd']].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Between Music Satisfaction and Mental Health Indicators 🔗🧠")
plt.show()
# Out:
# C:\Users\dell\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128279 (\N{LINK SYMBOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129504 (\N{BRAIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Summary
#     Column Used = music_effects
#
#     Analysis Dimensions = age group, streaming service, hours listening, mental health scores
#
#     Visualization Libraries = Matplotlib, Seaborn
#
#     Captions are included before every plot to understand the better way and improve the readebility
